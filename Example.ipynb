# %% [markdown]
# # Jupyter Notebook
#
# Jupyter notebooks are helpful to explain your code stepwise, make use of the Markdown Blocks to add text, equations, links, images etc..

# %% [markdown]
# # 1.) Generate Data and  apply equation
#
# The equation
# $$
# f(x) = x^2 \sin(\frac{1}{x})
# $$
# can be applied to any $x \in (0,\inf]$

# %%
import numpy as np 
import matplotlib.pyplot as plt
from src.helpers import amazing_function


x = np.linspace(1e-10, 0.05,num=1000)
y = amazing_function(x)

# %% [markdown]
# # 2.) Generate Plot

# %%
plt.plot(x,y)
plt.title("amazing function")
plt.xlabel("time [s]")
plt.ylabel("Amplitude")
plt.show()
